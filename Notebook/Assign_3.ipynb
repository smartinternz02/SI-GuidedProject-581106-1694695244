# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/home/godslayer/Desktop/Smart_Internz_Assignment/Practice/Data_set/penguins_size.csv')
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
shape=df.shape
print("Shape of the data set is: ",shape)
info=df.info()
print(info)
# Out:
# Shape of the data set is:  (344, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
# None

# %% [markdown]
# ## Finding Null values

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %% [markdown]
# ## Replacing Null values

# %%
# replacing na values
column=['culmen_length_mm','culmen_depth_mm','flipper_length_mm','body_mass_g']
for i in column:
    df[i].fillna(df[i].mean(),inplace=True)

# %%
# Checking for unique value in the data set
unique_val=['species','island','sex']
for i in unique_val:
    print(i,df[i].unique())
# Out:
# species ['Adelie' 'Chinstrap' 'Gentoo']
# island ['Torgersen' 'Biscoe' 'Dream']
# sex ['MALE' 'FEMALE' nan '.']

# %%
# Since there is only one row value with non nan or noisy data we can drop it or replace it we will replace it with the mode of the data set
df['sex']=df['sex'].replace('[.]',np.nan,regex=True)
# Replacing nan value in sex with mode
df['sex'].fillna(df['sex'].mode()[0],inplace=True)
print(df['sex'].unique())
print(df.head())
# Out:
# ['MALE' 'FEMALE']
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen          39.10000         18.70000         181.000000
# 1  Adelie  Torgersen          39.50000         17.40000         186.000000
# 2  Adelie  Torgersen          40.30000         18.00000         195.000000
# 3  Adelie  Torgersen          43.92193         17.15117         200.915205
# 4  Adelie  Torgersen          36.70000         19.30000         193.000000
#
#    body_mass_g     sex
# 0  3750.000000    MALE
# 1  3800.000000  FEMALE
# 2  3250.000000  FEMALE
# 3  4201.754386    MALE
# 4  3450.000000  FEMALE

# %%
# Counting value checking for imbalance data set
for i in unique_val:
    print(df[i].value_counts(),end="\n\n\n")
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64
#
#
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64
#
#
# sex
# MALE      179
# FEMALE    165
# Name: count, dtype: int64

# %%
# Checking for null values
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm     False
# culmen_depth_mm      False
# flipper_length_mm    False
# body_mass_g          False
# sex                  False
# dtype: bool

# %% [markdown]
# ## Univariate Analysis

# %%
sns.distplot(df['culmen_length_mm'])
# Out:
# /tmp/ipykernel_130044/1101064328.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['culmen_length_mm'])
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.distplot(df['culmen_depth_mm'])
# Out:
# /tmp/ipykernel_130044/1542393613.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['culmen_depth_mm'])
# <Axes: xlabel='culmen_depth_mm', ylabel='Density'>

# %%
sns.distplot(df['flipper_length_mm'])
# Out:
# /tmp/ipykernel_130044/2376148029.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['flipper_length_mm'])
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.distplot(df['body_mass_g'])
# Out:
# /tmp/ipykernel_130044/2151326810.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['body_mass_g'])
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
# Percentage of species
plt.pie(df['species'].value_counts(),labels=df['species'].unique(),autopct='%1.1f%%')
plt.title("Percentage of species")
# Out:
# Text(0.5, 1.0, 'Percentage of species')

# %%
display(df['island'].value_counts())
plt.pie(df['island'].value_counts(),labels=['Biscone','Dream','Torgersen'],autopct='%1.1f%%')
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64
# ([<matplotlib.patches.Wedge at 0x7f5b3beda3d0>,
# ...
#  [Text(0.040174244511466346, 1.099266132507471, 'Biscone'),
#   Text(-0.5383596868970475, -0.9592543184808255, 'Dream'),
#   Text(0.9782763205126381, -0.502966639772713, 'Torgersen')],
#  [Text(0.021913224278981642, 0.5995997086404388, '48.8%'),
#   Text(-0.29365073830748045, -0.5232296282622685, '36.0%'),
#   Text(0.5336052657341662, -0.2743454398760253, '15.1%')])

# %%
plt.scatter(df['culmen_length_mm'],df['culmen_depth_mm'])
plt.xlabel("culmen_length_mm")
plt.ylabel("culmen_depth_mm")
plt.title("culmen_length_mm vs culmen_depth_mm")
# Out:
# Text(0.5, 1.0, 'culmen_length_mm vs culmen_depth_mm')

# %%
sns.barplot(x=df.sex.value_counts().index,y=df.sex.value_counts())
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(x=df.island.value_counts().index,y=df.island.value_counts())
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# ## Bivariate

# %%
sns.lineplot(x=df['culmen_length_mm'],y=df['culmen_depth_mm'],hue=df['species'])
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.lineplot(x=df['flipper_length_mm'],y=df['body_mass_g'])
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(x=df['culmen_length_mm'],y=df['culmen_depth_mm'],hue=df['species'])
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.scatterplot(x=df['flipper_length_mm'],y=df['body_mass_g'],hue=df['species'])
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %% [markdown]
# ## Multivariate

# %%
sns.pairplot(df,hue='species')
# Out:
# /home/godslayer/.local/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Correlation of taget variable with other variable
# Before encoding the data set
# Out:
# <Axes: >

# %% [markdown]
# ## Outlier Detection

# %%
for i in column:
    sns.boxplot(df[i])
    plt.title(i)
    plt.show()

# %% [markdown]
# <h2>There are no outliers so no need to remove</h2>

# %% [markdown]
# ## Descriptive Statistics

# %%
display(df.describe())
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        344.000000       344.000000         344.000000   344.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.443643         1.969027          14.020657   799.613058
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.275000        15.600000         190.000000  3550.000000
# 50%           44.250000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   344 non-null    float64
#  3   culmen_depth_mm    344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ## Encoding the data
#
# <p>We perform label encoding and avoid one hot encoding as the data dimensonality will increase</p>

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
# since nan is there we need to replace it as well in sex column

df['species']=le.fit_transform(df['species'])
df['island']=le.fit_transform(df['island'])
# encoding the categorical data
print(df['sex'].unique())
df['sex']=le.fit_transform(df['sex'])
# Out:
# ['MALE' 'FEMALE']

# %%
df.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2          39.10000         18.70000         181.000000
# 1        0       2          39.50000         17.40000         186.000000
# 2        0       2          40.30000         18.00000         195.000000
# 3        0       2          43.92193         17.15117         200.915205
# 4        0       2          36.70000         19.30000         193.000000
#
#    body_mass_g  sex
# 0  3750.000000    1
# 1  3800.000000    0
# 2  3250.000000    0
# 3  4201.754386    1
# 4  3450.000000    0

# %% [markdown]
# ## Correlation with target variable

# %%
corr_mat=df.corr()
sns.heatmap(corr_mat,annot=True)
corr_mat['species'].sort_values(ascending=False)
# Out:
# species              1.000000
# flipper_length_mm    0.851160
# body_mass_g          0.747726
# culmen_length_mm     0.728674
# sex                  0.010240
# island              -0.635659
# culmen_depth_mm     -0.741335
# Name: species, dtype: float64

# %%
X=df.drop('species',axis=1)
y=df['species']
# After splitting 
display(X.head())
display(y.head())
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0       2          39.10000         18.70000         181.000000  3750.000000
# 1       2          39.50000         17.40000         186.000000  3800.000000
# 2       2          40.30000         18.00000         195.000000  3250.000000
# 3       2          43.92193         17.15117         200.915205  4201.754386
# 4       2          36.70000         19.30000         193.000000  3450.000000
#
#    sex
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: species, dtype: int64

# %% [markdown]
# ## Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_Scaled=scaler.fit_transform(X)
X_Scaled=pd.DataFrame(X_Scaled,columns=X.columns)
X_Scaled.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0     1.0          0.254545         0.666667           0.152542     0.291667
# 1     1.0          0.269091         0.511905           0.237288     0.305556
# 2     1.0          0.298182         0.583333           0.389831     0.152778
# 3     1.0          0.429888         0.482282           0.490088     0.417154
# 4     1.0          0.167273         0.738095           0.355932     0.208333
#
#    sex
# 0  1.0
# 1  0.0
# 2  0.0
# 3  1.0
# 4  0.0

# %% [markdown]
# ## Splitting the data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_Scaled,y,test_size=0.2,random_state=1)

# %%
X_train.shape
# Out:
# (275, 6)

# %%
X_test.shape
# Out:
# (69, 6)

# %%
y_train.shape
# Out:
# (275,)

# %%
y_test.shape
# Out:
# (69,)

# %%
# importing Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_test=dt.predict(X_test)
pred_train=dt.predict(X_train)

# %%
check_test=pd.DataFrame({'Actual':y_test,'Predicted':pred_test})
check_test.head()
# Out:
#      Actual  Predicted
# 306       2          2
# 341       2          2
# 291       2          2
# 102       0          0
# 289       2          2

# %%
check_train=pd.DataFrame({'Actual':y_train,'Predicted':pred_train})
check_train.head()
# Out:
#      Actual  Predicted
# 150       0          0
# 105       0          0
# 112       0          0
# 162       1          1
# 328       2          2

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print("Accuracy score of train data is: ",accuracy_score(y_train,pred_train))
print("Accuracy score of test data is: ",accuracy_score(y_test,pred_test))
# Out:
# Accuracy score of train data is:  1.0
# Accuracy score of test data is:  0.9710144927536232
